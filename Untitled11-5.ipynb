# %%
# -*- coding: utf-8 -*-
import os, cv2, re, numpy as np, warnings, random
import tensorflow as tf
import librosa, whisper, easyocr
import matplotlib.pyplot as plt
from moviepy import VideoFileClip
from tensorflow.keras import layers, models, regularizers, backend as K
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import class_weight
import seaborn as sns

warnings.filterwarnings("ignore")

# ===============================
# CONFIG
# ===============================
BASE_DATASET = r"D:\web\cnn_dnn_rnn_gan\Dataset"
PROCESSED_DATA_FILE = "processed_data_optimized.npz"
MODEL_FILE = "best_multimodal_model.h5"

IMG_SIZE = (224, 224)
SPEC_SIZE = (128, 128)
MAX_TEXT_LEN = 100
SR = 22050
DURATION = 3
BATCH_SIZE = 8
EPOCHS = 20

# ===============================
# LOAD MODELS
# ===============================
print("Initializing AI Engines (Whisper, EasyOCR)...")
stt_model = whisper.load_model("base")
ocr_reader = easyocr.Reader(['id', 'en'], gpu=True)

# ===============================
# FEATURE EXTRACTION (MULTIMODAL)
# ===============================
def extract_frame(video_path):
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.set(cv2.CAP_PROP_POS_FRAMES, total // 2)
    ret, frame = cap.read()
    cap.release()
    if not ret: return np.zeros((*IMG_SIZE, 3))
    frame = cv2.resize(frame, IMG_SIZE)
    return (frame / 255.0).astype(np.float32)

def extract_audio(video_path):
    tmp = f"temp_proc_{os.getpid()}.wav"
    try:
        with VideoFileClip(video_path) as video:
            if video.audio is None: return np.zeros((*SPEC_SIZE, 1)), ""
            video.audio.write_audiofile(tmp, logger=None)
        
        y, sr = librosa.load(tmp, sr=SR)
        if len(y) < SR * DURATION: 
            y = np.pad(y, (0, SR * DURATION - len(y)))
        y = y[:SR * DURATION]
        
        # Audio Augmentation (Noise Injection)
        y = y + 0.002 * np.random.randn(len(y))
        
        mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        mel = cv2.resize(librosa.power_to_db(mel), SPEC_SIZE)
        mel = np.expand_dims(mel, -1)
        mel = (mel - np.mean(mel)) / (np.std(mel) + 1e-9)
        
        text = ""
        try: 
            text = stt_model.transcribe(tmp)['text']
        except: pass
        
        if os.path.exists(tmp): os.remove(tmp)
        return mel.astype(np.float32), text.lower()
    except:
        if os.path.exists(tmp): os.remove(tmp)
        return np.zeros((*SPEC_SIZE, 1)), ""

def extract_text_ocr(frame):
    try:
        frame_uint8 = (frame * 255).astype(np.uint8)
        text = " ".join(ocr_reader.readtext(frame_uint8, detail=0))
        return text.lower()
    except: return ""

def text_to_sequence(text):
    text = re.sub(r'[^a-zA-Z ]', '', text)
    seq = [ord(c) % 5000 for c in text][:MAX_TEXT_LEN]
    seq += [0] * (MAX_TEXT_LEN - len(seq))
    return np.array(seq)

# ===============================
# DATA LOADER
# ===============================
def load_dataset():
    if os.path.exists(PROCESSED_DATA_FILE):
        print("Loading cached data from disk...")
        d = np.load(PROCESSED_DATA_FILE)
        return d['X_img'], d['X_spec'], d['X_txt'], d['y']
    
    X_img, X_spec, X_txt, y = [], [], [], []
    categories = {'nonkasar': 0, 'kasar': 1}
    
    for cat_name, label in categories.items():
        cat_path = os.path.join(BASE_DATASET, cat_name)
        if not os.path.exists(cat_path): continue
        
        for root, dirs, files in os.walk(cat_path):
            if ".ipynb_checkpoints" in root: continue
            for f in files:
                if f.lower().endswith((".mp4", ".avi")):
                    full_path = os.path.join(root, f)
                    try:
                        img = extract_frame(full_path)
                        spec, txt_a = extract_audio(full_path)
                        txt_o = extract_text_ocr(img)
                        txt_final = text_to_sequence(txt_a + " " + txt_o)
                        
                        X_img.append(img); X_spec.append(spec)
                        X_txt.append(txt_final); y.append(label)
                        print(f"[LOADED] {f}")
                    except: continue
                        
    X_i, X_s, X_t, Y = np.array(X_img), np.array(X_spec), np.array(X_txt), np.array(y)
    np.savez(PROCESSED_DATA_FILE, X_img=X_i, X_spec=X_s, X_txt=X_t, y=Y)
    return X_i, X_s, X_t, Y

# ===============================
# ADAPTIVE FUSION COMPONENT
# ===============================
@tf.keras.utils.register_keras_serializable()
class AdaptiveFusion(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.attention_net = models.Sequential([
            layers.Dense(64, activation='relu'),
            layers.Dense(3, activation='softmax')
        ])

    def call(self, inputs):
        v, a, t = inputs
        combined = layers.concatenate([v, a, t])
        weights = self.attention_net(combined)
        wv = K.expand_dims(weights[:, 0], -1)
        wa = K.expand_dims(weights[:, 1], -1)
        wt = K.expand_dims(weights[:, 2], -1)
        return layers.concatenate([v * wv, a * wa, t * wt])

# ===============================
# MODEL ARCHITECTURE
# ===============================
def build_optimized_model():
    in_img = layers.Input(shape=(*IMG_SIZE, 3))
    base_cnn = EfficientNetB0(include_top=False, weights='imagenet', input_tensor=in_img)
    base_cnn.trainable = False
    v = layers.GlobalAveragePooling2D()(base_cnn.output)
    v = layers.Dense(128, activation='relu')(v)

    in_spec = layers.Input(shape=(*SPEC_SIZE, 1))
    a = layers.Conv2D(32, 3, activation='relu', padding='same')(in_spec)
    a = layers.MaxPooling2D()(a)
    a = layers.Conv2D(64, 3, activation='relu', padding='same')(a)
    a = layers.MaxPooling2D()(a)
    a = layers.Flatten()(a)
    a = layers.Dense(128, activation='relu')(a)

    in_txt = layers.Input(shape=(MAX_TEXT_LEN,))
    t = layers.Embedding(5000, 64)(in_txt)
    t = layers.Bidirectional(layers.LSTM(64))(t)
    t = layers.Dense(128, activation='relu')(t)

    fused = AdaptiveFusion()([v, a, t])

    x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01))(fused)
    x = layers.Dropout(0.5)(x)
    x = layers.BatchNormalization()(x)
    out = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model([in_img, in_spec, in_txt], out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4), 
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

# ===============================
# VISUALIZATION FUNCTIONS
# ===============================
def plot_training_results(history):
    plt.figure(figsize=(12, 5))
    # Plot Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()
    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()
    plt.show()

def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, (y_pred > 0.5).astype(int))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Non-Kasar', 'Kasar'], yticklabels=['Non-Kasar', 'Kasar'])
    plt.title('Confusion Matrix Heatmap')
    plt.xlabel('Predicted Label'); plt.ylabel('True Label')
    plt.show()

# ===============================
# PREDICTION & TESTING
# ===============================
def predict_single(file_path, model):
    img = extract_frame(file_path)
    spec, txt_a = extract_audio(file_path)
    txt_o = extract_text_ocr(img)
    txt_seq = text_to_sequence(txt_a + " " + txt_o)
    
    pred = model.predict([
        np.expand_dims(img, 0), 
        np.expand_dims(spec, 0), 
        np.expand_dims(txt_seq, 0)
    ], verbose=0)[0][0]
    
    label = "Kasar" if pred >= 0.5 else "Non-Kasar"
    score = pred if pred >= 0.5 else (1-pred)
    return label, score

def run_mass_test(model):
    print("\n" + "="*60)
    print("RUNNING MASSIVE TEST (10 FILES PER SUB-FOLDER)")
    print("="*60)
    for main_cat in ['kasar', 'nonkasar']:
        main_path = os.path.join(BASE_DATASET, main_cat)
        if not os.path.exists(main_path): continue
        subs = [d for d in os.listdir(main_path) if os.path.isdir(os.path.join(main_path, d))]
        for sub in subs:
            if sub == ".ipynb_checkpoints": continue
            sub_full = os.path.join(main_path, sub)
            files = [f for f in os.listdir(sub_full) if f.lower().endswith(".mp4")]
            test_files = random.sample(files, min(len(files), 10))
            print(f"\n--- Sub-Folder: {sub} ---")
            for fname in test_files:
                fpath = os.path.join(sub_full, fname)
                res, acc = predict_single(fpath, model)
                print(f"[{res}] {acc*100:.2f}% | File: {fname[:50]}...")

# ===============================
# MAIN EXECUTION
# ===============================
def main():
    X_i, X_s, X_t, Y = load_dataset()
    X_i_tr, X_i_val, X_s_tr, X_s_val, X_t_tr, X_t_val, Y_tr, Y_val = train_test_split(
        X_i, X_s, X_t, Y, test_size=0.2, stratify=Y, random_state=42)
    
    if not os.path.exists(MODEL_FILE):
        print("Training Model...")
        cw = dict(enumerate(class_weight.compute_class_weight('balanced', classes=np.unique(Y_tr), y=Y_tr)))
        model = build_optimized_model()
        history = model.fit(
            [X_i_tr, X_s_tr, X_t_tr], Y_tr,
            validation_data=([X_i_val, X_s_val, X_t_val], Y_val),
            epochs=EPOCHS, batch_size=BATCH_SIZE,
            class_weight=cw,
            callbacks=[tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)]
        )
        model.save(MODEL_FILE)
        plot_training_results(history)
    else:
        print("Loading existing best model...")
        model = tf.keras.models.load_model(MODEL_FILE, custom_objects={'AdaptiveFusion': AdaptiveFusion})

    # Evaluasi & Visualisasi Akhir
    preds = model.predict([X_i_val, X_s_val, X_t_val])
    print("\n--- Final Classification Report ---")
    print(classification_report(Y_val, (preds > 0.5).astype(int), target_names=['Non-Kasar', 'Kasar']))
    plot_confusion_matrix(Y_val, preds)

    # Jalankan Test Otomatis
    run_mass_test(model)

if __name__ == "__main__":
    main()
# Out:
# Initializing AI Engines (Whisper, EasyOCR)...
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Loading cached data from disk...
# Training Model...
# WARNING:tensorflow:From D:\web\cnn_dnn_rnn_gan\venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 59s 260ms/step - accuracy: 0.7728 - loss: 3.0602 - val_accuracy: 0.7337 - val_loss: 2.7157
# Epoch 2/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 237ms/step - accuracy: 0.8468 - loss: 2.1427 - val_accuracy: 0.7899 - val_loss: 1.9495
# Epoch 3/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 237ms/step - accuracy: 0.8823 - loss: 1.5467 - val_accuracy: 0.8609 - val_loss: 1.3861
# Epoch 4/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9275 - loss: 1.1123 - val_accuracy: 0.8254 - val_loss: 1.2120
# Epoch 5/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 253ms/step - accuracy: 0.9519 - loss: 0.8337 - val_accuracy: 0.8698 - val_loss: 0.9033
# Epoch 6/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 48s 282ms/step - accuracy: 0.9489 - loss: 0.6532 - val_accuracy: 0.8373 - val_loss: 0.9645
# Epoch 7/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 44s 258ms/step - accuracy: 0.9741 - loss: 0.4975 - val_accuracy: 0.8876 - val_loss: 0.8203
# Epoch 8/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.9889 - loss: 0.3919 - val_accuracy: 0.8698 - val_loss: 0.7723
# Epoch 9/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 48s 286ms/step - accuracy: 0.9711 - loss: 0.3795 - val_accuracy: 0.8728 - val_loss: 0.7400
# Epoch 10/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 253ms/step - accuracy: 0.9837 - loss: 0.3034 - val_accuracy: 0.8284 - val_loss: 0.9497
# Epoch 11/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 46s 274ms/step - accuracy: 0.9741 - loss: 0.2873 - val_accuracy: 0.8698 - val_loss: 0.7907
# Epoch 12/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 48s 285ms/step - accuracy: 0.9815 - loss: 0.2453 - val_accuracy: 0.8728 - val_loss: 0.7305
# Epoch 13/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 45s 267ms/step - accuracy: 0.9800 - loss: 0.2192 - val_accuracy: 0.8905 - val_loss: 0.5951
# Epoch 14/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 45s 266ms/step - accuracy: 0.9889 - loss: 0.1933 - val_accuracy: 0.8728 - val_loss: 0.6876
# Epoch 15/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 45s 268ms/step - accuracy: 0.9904 - loss: 0.1637 - val_accuracy: 0.8521 - val_loss: 0.8415
# Epoch 16/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 243ms/step - accuracy: 0.9882 - loss: 0.1562 - val_accuracy: 0.8639 - val_loss: 0.7411
# Epoch 17/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 252ms/step - accuracy: 0.9874 - loss: 0.1505 - val_accuracy: 0.8402 - val_loss: 0.7364
# Epoch 18/20
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 47s 281ms/step - accuracy: 0.9926 - loss: 0.1218 - val_accuracy: 0.8609 - val_loss: 0.8551
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 785ms/step
#
# --- Final Classification Report ---
#               precision    recall  f1-score   support
#
#    Non-Kasar       0.92      0.83      0.87       153
#        Kasar       0.87      0.94      0.90       185
#
#     accuracy                           0.89       338
#    macro avg       0.90      0.89      0.89       338
# weighted avg       0.89      0.89      0.89       338
# ============================================================
# RUNNING MASSIVE TEST (10 FILES PER SUB-FOLDER)
# ============================================================
#
# --- Sub-Folder: Anjing ---
# [Kasar] 99.98% | File: dasar_siapa-__storykatakata__fyp__horrorvibes__the...
# [Kasar] 99.72% | File: anjing_lu_ah__fyppppppppppppppppppppppp___TubeTren...
# [Kasar] 99.95% | File: Gemoynya_peanut___anabulkesayangan__poodle__poodle...
# [Kasar] 99.86% | File: itu_lah_diriru_berani_nya_main_belakang__TubeTrend...
# [Kasar] 99.99% | File: Do_you_like_the_Kuchi_Kuchi---____________________...
# [Kasar] 99.89% | File: siapa_yang_paling_anjing_kau_______TubeTrendy__752...
# [Kasar] 99.98% | File: kucing_berantem_sama_anjing-__fyp____TubeTrendy__7...
# [Kasar] 99.98% | File: _TubeTrendy__7547217811014176005.mp4...
# [Kasar] 99.97% | File: _TubeTrendy__7091041898252537114.mp4...
# [Kasar] 99.97% | File: anjing--babi_lu------__TubeTrendy__755477210700407...
#
# --- Sub-Folder: Babi ---
# [Kasar] 99.98% | File: _-pada_ngomong_apa_klean_asik_bener____iduladha__s...
# [Kasar] 99.89% | File: hahhh_huhhh___kristoba2___krispinus__randomparlili...
# [Kasar] 99.89% | File: lah_kok_ada_babi____fyppppppppppppppppppppppp__vir...
# [Kasar] 99.88% | File: _hanyamemejangandibawaserius__fypppppppppppppppppp...
# [Kasar] 99.98% | File: ______lucu__hiburan__harirayaiduladha2022__fyp__Tu...
# [Kasar] 99.99% | File: 3_babi_stecu__stecu__babygemoy__babilucu___TubeTre...
# [Kasar] 99.79% | File: _TubeTrendy__7327167626751331590.mp4...
# [Kasar] 99.98% | File: Bagoyang_____TubeTrendy__7553187155430935819.mp4...
# [Kasar] 99.93% | File: babi_babiku____fyppp__soundviral__TubeTrendy__7519...
# [Kasar] 99.96% | File: babi_babi_babi_luu___ff_anti____fypppppppppppppppp...
#
# --- Sub-Folder: Bajingan ---
# [Kasar] 99.95% | File: bajingan_bajingan------_hawane_pengen_misuh__jowop...
# [Kasar] 99.94% | File: _TubeTrendy__7548492838703533317.mp4...
# [Kasar] 99.97% | File: _fyp__fypagee__fypages__fypage___masukberandafyp__...
# [Kasar] 99.94% | File: coba_kalian_tanya_kalau_gak_bisa_maaf_ya_-_-______...
# [Kasar] 99.95% | File: be_strong_boy-__palembang__bajingan__masukberanda_...
# [Kasar] 99.96% | File: _LauraBasuki_kayaknya_sakit_hati_banget_nih_sama__...
# [Kasar] 99.96% | File: lnngn_cngkmn-__fyp__ungarancidro___TubeTrendy__732...
# [Kasar] 99.89% | File: Rabban__hab_lan__min_azw_jin__wa_dzurriyy_tin__qur...
# [Kasar] 99.93% | File: bajingannnn_nek_bengi_jomblone_kroso_banget__jowop...
# [Kasar] 99.97% | File: _foryou__fyp__xyzbca___TubeTrendy__753180956089450...
#
# --- Sub-Folder: Bangsat ---
# [Kasar] 99.97% | File: _TubeTrendy__7529723998846913812.mp4...
# [Kasar] 99.98% | File: _TubeTrendy__7389649355491331334.mp4...
# [Kasar] 99.90% | File: mau_cape_tapiiii__TubeTrendy__7530263558391680264....
# [Kasar] 99.93% | File: _temen__berandatiktok__fyp__fy__katabijak__storyka...
# [Kasar] 99.86% | File: cuma_mau_bilang_bangsat__meme__magelang24jam__fyp_...
# [Kasar] 99.99% | File: _TubeTrendy__7547671742068673797.mp4...
# [Kasar] 99.91% | File: _TubeTrendy__7451218778580356358.mp4...
# [Kasar] 99.99% | File: _TubeTrendy__7496468434750885125.mp4...
# [Kasar] 99.93% | File: _fyp__foryou__foryourpage__fyp__viral__foryoupageo...
# [Kasar] 99.99% | File: _TubeTrendy__7522106279955909944.mp4...
#
# --- Sub-Folder: Goblok ---
# [Kasar] 99.99% | File: _TubeTrendy__7536937194607496455.mp4...
# [Kasar] 99.96% | File: Kalian_pasti_bingung_kan-_Yg_bikin_Vt_juga_ngetikn...
# [Kasar] 99.95% | File: Goblok_artinya_Cantik_versi_Bocil_Kevin_Jo_China_I...
# [Kasar] 99.94% | File: goblok_4upage__fypp__freefire___TubeTrendy__754687...
# [Kasar] 96.16% | File: _harisprst_-AnJiNg_SiIIIi_EtA_gObLoK-_mUsIk___----...
# [Kasar] 99.97% | File: bodoh_boleh__tolol_jangan__bodoh_masih_bisa_belaja...
# [Kasar] 99.97% | File: makin_gede_makin_makin__animasi__animasilucu__anim...
# [Kasar] 98.17% | File: rivev_ajg___brainrot__anomali__bismillahfyp__fypag...
# [Kasar] 99.94% | File: _heppyasmara__liriklagu__lipsync__fypppppppppppppp...
# [Kasar] 99.91% | File: Tolol_-_Meme_Effect_Sound_Thanks_for_watching_Help...
#
# --- Sub-Folder: Jancuk ---
# [Kasar] 99.93% | File: raimu_cukk__TubeTrendy__7155463058825956634.mp4...
# [Kasar] 99.98% | File: _lyrics___TubeTrendy__7549072971118251320.mp4...
# [Kasar] 99.99% | File: psyware_sam_Ojo_baperan_Yo_____persebayasurabaya__...
# [Kasar] 99.96% | File: __jancok_kui_ra_misuh____TubeTrendy__6891212651775...
# [Kasar] 99.99% | File: nggak_tuku-_ribut_Jancok__meme__ribut__clipmeme__p...
# [Non-Kasar] 99.59% | File: ____________________--______________notifwhatsapp_...
# [Kasar] 99.94% | File: Dunia_itu_jahat_untuk_laki_laki___TubeTrendy__7549...
# [Kasar] 99.98% | File: _jancokkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk___TubeTre...
# [Kasar] 99.98% | File: Kayaknya_refrein_lagunya_Pak__SujiwoTejo_yg_ini_la...
# [Kasar] 99.97% | File: Bagian_ll_janc-k_unggerr__TubeTrendy__752697842171...
#
# --- Sub-Folder: Tai ---
# [Kasar] 99.95% | File: _TubeTrendy__7349534268655291653.mp4...
# [Kasar] 99.99% | File: _tamlinh__tailo__mayman___TubeTrendy__750112891520...
# [Kasar] 99.99% | File: _TubeTrendy__7544327574575385863.mp4...
# [Kasar] 68.25% | File: _Nartineutox__bukanwanitabiasa__ketemu_orang_lagi_...
# [Kasar] 80.66% | File: siapa_pernah_kejadian_kek_ngini__TubeTrendy__74440...
# [Kasar] 99.92% | File: _talo__gamest_rareloralala___fyppppppppppppppppppp...
# [Kasar] 99.99% | File: TALIYO__TubeTrendy__7536635933794258232.mp4...
# [Kasar] 99.98% | File: _pocket__design__foryoupage______bigbosstailo_____...
# [Kasar] 99.86% | File: _wedding__tariantradisional__seluma__talo___TubeTr...
# [Kasar] 99.98% | File: _n_m_ng_s_m_10k_like___xh_xz11020_xuhuong_amnhacva...
#
# --- Sub-Folder: Tolol ---
# [Kasar] 99.98% | File: ketika_kau_berantam_sama_orang_sumbing-______fyppp...
# [Kasar] 99.96% | File: kata_tolol_itu_arti_nya_kebalikan_nya_pintar-pinte...
# [Kasar] 99.97% | File: _TubeTrendy__7555847466826910994.mp4...
# [Kasar] 100.00% | File: _fyp__fypage___TubeTrendy__7539511338305998088.mp4...
# [Kasar] 99.92% | File: Tertawalah_sepuasnya_____kocak__asfmineee__asfmine...
# [Kasar] 99.96% | File: part_ini_gong_banget___drtirta___TubeTrendy__75165...
# [Kasar] 99.97% | File: _4u__galaubrutal__xyzbca___TubeTrendy__74002929777...
# [Kasar] 99.83% | File: _rhomairama__rhomairama_sonetagroup___rhomairamaof...
# [Kasar] 99.98% | File: __avoidant_silent_fyp__caput___TubeTrendy__7513848...
# [Kasar] 99.83% | File: VERY__TOLOL______tolol___KeluargaSehatIndonesiaKua...
#
# --- Sub-Folder: nonanjing ---
# [Non-Kasar] 98.93% | File: 1ab_Q4UHGrU.mp4...
# [Non-Kasar] 99.86% | File: 6uI_dtXw5VQ.mp4...
# [Non-Kasar] 99.88% | File: _Uw3QwQ-Vug.mp4...
# [Non-Kasar] 100.00% | File: 6AFs5aZ7CG4.mp4...
# [Non-Kasar] 99.47% | File: 4if23oJG32k.mp4...
# [Non-Kasar] 100.00% | File: 4B74Zsv_BHc.mp4...
# [Non-Kasar] 99.03% | File: 5K92Ij3Zs4E.mp4...
# [Non-Kasar] 97.29% | File: _Nwp5oIfGg0.mp4...
# [Non-Kasar] 99.95% | File: 0z6M30DyW3k.mp4...
# [Non-Kasar] 99.47% | File: _CCJKveW6c8.mp4...
#
# --- Sub-Folder: nonbabi ---
# [Non-Kasar] 98.98% | File: ag6e3qKkE5M.mp4...
# [Non-Kasar] 99.99% | File: 839tfUtjIi0.mp4...
# [Non-Kasar] 99.97% | File: 8wSE-EOYkGk.mp4...
# [Non-Kasar] 99.71% | File: 8cNehasauwY.mp4...
# [Non-Kasar] 99.99% | File: 43b4Yu_hxss.mp4...
# [Non-Kasar] 99.98% | File: 41IVUCA4Qso.mp4...
# [Kasar] 99.51% | File: 8jS2LuwGveU.mp4...
# [Non-Kasar] 99.68% | File: 8drbNHk4bgg.mp4...
# [Non-Kasar] 99.99% | File: 9pRspxatIOM.mp4...
# [Non-Kasar] 99.97% | File: aZGDqWFoq7s.mp4...
#
# --- Sub-Folder: nonbajingan ---
# [Non-Kasar] 94.48% | File: Csn6F6Lj7Rc.mp4...
# [Non-Kasar] 99.98% | File: EM2q4D8yOmQ.mp4...
# [Non-Kasar] 97.04% | File: dLAR-qxWBtc.mp4...
# [Non-Kasar] 97.34% | File: UqfTulUp9yw.mp4...
# [Non-Kasar] 100.00% | File: mhw_FdYbB0I.mp4...
# [Non-Kasar] 100.00% | File: e_WbLIlCL78.mp4...
# [Non-Kasar] 68.14% | File: b-lHKbLjsLg.mp4...
# [Non-Kasar] 99.94% | File: DMii0PHwzJ8.mp4...
# [Non-Kasar] 88.42% | File: DSNm_e45sfk.mp4...
# [Non-Kasar] 96.53% | File: bKmNVtpmADU.mp4...
#
# --- Sub-Folder: nonbangsat ---
# [Non-Kasar] 99.99% | File: IzPgpxcu_Ss.mp4...
# [Non-Kasar] 99.97% | File: ibsWV1naas4.mp4...
# [Non-Kasar] 93.17% | File: FoWenAxVvGo.mp4...
# [Non-Kasar] 99.89% | File: Gat_qoFDyt8.mp4...
# [Non-Kasar] 100.00% | File: HnHSVaPKMbU.mp4...
# [Non-Kasar] 99.97% | File: uWxX0m1_-o0.mp4...
# [Non-Kasar] 99.80% | File: iX-aUmAyZZk.mp4...
# [Non-Kasar] 99.98% | File: Gy8VfkgCxBQ.mp4...
# [Non-Kasar] 91.00% | File: FP0YC2Uhbbs.mp4...
# [Non-Kasar] 99.98% | File: H1v5U7ITo-A.mp4...
#
# --- Sub-Folder: nongoblok ---
# [Non-Kasar] 97.55% | File: Lz7Drdz-vLg.mp4...
# [Non-Kasar] 100.00% | File: KwNMYeiSMvI.mp4...
# [Non-Kasar] 99.48% | File: jGLuzr15JzI.mp4...
# [Non-Kasar] 64.14% | File: KZgWRuKxm7k.mp4...
# [Non-Kasar] 97.23% | File: kSOctAeWhTY.mp4...
# [Non-Kasar] 100.00% | File: Lv9NyO_SJ5E.mp4...
# [Non-Kasar] 99.10% | File: uyyLot4PLXM.mp4...
# [Non-Kasar] 98.31% | File: LER3mvXZY2Q.mp4...
# [Non-Kasar] 99.98% | File: lPdY7BTcmA0.mp4...
# [Non-Kasar] 96.23% | File: j4cGkfKt1xE.mp4...
#
# --- Sub-Folder: nonjancuk ---
# [Non-Kasar] 99.97% | File: MLSANrmh9Ko.mp4...
# [Non-Kasar] 98.90% | File: otpm4F0S7rU.mp4...
# [Non-Kasar] 99.30% | File: mcl4aolNly8.mp4...
# [Non-Kasar] 99.99% | File: MQsgVGbCmDo.mp4...
# [Non-Kasar] 100.00% | File: -Nly_L_f4Ng.mp4...
# [Non-Kasar] 99.94% | File: oHkHHU2xhZU.mp4...
# [Non-Kasar] 99.75% | File: NTAhpVSAKpQ.mp4...
# [Kasar] 99.77% | File: q--3hAhvWtE.mp4...
# [Non-Kasar] 61.39% | File: NN3e6hoOOLE.mp4...
# [Non-Kasar] 99.96% | File: NXzTB6CAq0g.mp4...
#
# --- Sub-Folder: nontai ---
# [Non-Kasar] 54.11% | File: sNthuIwDCyU.mp4...
# [Non-Kasar] 100.00% | File: RnVC25BmyhI.mp4...
# [Non-Kasar] 99.98% | File: turY5vu4fvk.mp4...
# [Non-Kasar] 100.00% | File: tj1WGQtpFVc.mp4...
# [Non-Kasar] 99.99% | File: qYLJW8Qa4VQ.mp4...
# [Non-Kasar] 99.80% | File: TjpWLAP4dWA.mp4...
# [Non-Kasar] 99.84% | File: U487gotA5Cs.mp4...
# [Non-Kasar] 99.69% | File: RIJA67s7qtY.mp4...
# [Non-Kasar] 99.96% | File: tBbdSzwxqyY.mp4...
# [Non-Kasar] 99.98% | File: s-BJVGSCQ78.mp4...
#
# --- Sub-Folder: nontolol ---
# [Non-Kasar] 99.99% | File: wHRvkKDtJGk.mp4...
# [Non-Kasar] 99.78% | File: ZgecMV2v_98.mp4...
# [Non-Kasar] 99.98% | File: znDkPpwXkJI.mp4...
# [Non-Kasar] 99.79% | File: xnK8c9hCvsU.mp4...
# [Non-Kasar] 99.98% | File: YWfv2O6PBCY.mp4...
# [Non-Kasar] 87.04% | File: WsCtZouV2MI.mp4...
# [Non-Kasar] 98.14% | File: xiONNDpLUWQ.mp4...
# [Non-Kasar] 99.97% | File: VBRj71PUiLU.mp4...
# [Non-Kasar] 90.68% | File: xbOaTxpZl9k.mp4...
# [Non-Kasar] 99.98% | File: zz4zoYRddjg.mp4...
